# %%
# !pip3 install git+https://github.com/MaayanLab/blitzgsea.git

# %%
import blitzgsea as blitz
import urllib.request
import pandas as pd

# download example gene expression signature
url = "https://github.com/MaayanLab/blitzgsea/raw/main/testing/ageing_muscle_gtex.tsv"
urllib.request.urlretrieve(url, "ageing_muscle_gtex.tsv")

# read signature as pandas dataframe
signature = pd.read_csv("ageing_muscle_gtex.tsv")

# list available gene set libraries in Enrichr
#blitz.enrichr.print_libraries()

# use enrichr submodule to retrieve gene set library
library = blitz.enrichr.get_library("KEGG_2021_Human")

# run enrichment analysis
result = blitz.gsea(signature, library)
# Out:
# {'LIBRARY_LIST_URL': 'https://maayanlab.cloud/speedrichr/api/listlibs', 'LIBRARY_DOWNLOAD_URL': 'https://maayanlab.cloud/Enrichr/geneSetLibrary?mode=text&libraryName='}
# 0 - GeneSigDB
# 1 - Enrichr_Submissions_TF-Gene_Coocurrence
# 2 - SysMyo_Muscle_Gene_Sets
# 3 - WikiPathway_2021_Human
# 4 - HomoloGene
# 5 - WikiPathways_2013
# 6 - OMIM_Disease
# 7 - Data_Acquisition_Method_Most_Popular_Genes
# 8 - Cancer_Cell_Line_Encyclopedia
# 9 - WikiPathways_2016
# 10 - WikiPathways_2015
# 11 - RNAseq_Automatic_GEO_Signatures_Human_Up
# 12 - Human_Gene_Atlas
# 13 - Kinase_Perturbations_from_GEO_down
# 14 - Disease_Signatures_from_GEO_down_2014
# 15 - Disease_Perturbations_from_GEO_up
# 16 - Old_CMAP_down
# 17 - MCF7_Perturbations_from_GEO_up
# 18 - NIH_Funded_PIs_2017_GeneRIF_ARCHS4_Predictions
# 19 - DepMap_WG_CRISPR_Screens_Sanger_CellLines_2019
# 20 - PPI_Hub_Proteins
# 21 - Disease_Signatures_from_GEO_up_2014
# 22 - GTEx_Tissue_Expression_Up
# 23 - L1000_Kinase_and_GPCR_Perturbations_up
# 24 - ARCHS4_Cell-lines
# 25 - VirusMINT
# 26 - KEGG_2019_Human
# 27 - ARCHS4_Tissues
# 28 - MGI_Mammalian_Phenotype_Level_4
# 29 - MGI_Mammalian_Phenotype_Level_3
# 30 - InterPro_Domains_2019
# 31 - KEGG_2015
# 32 - MSigDB_Computational
# 33 - TF-LOF_Expression_from_GEO
# 34 - KEGG_2013
# 35 - GWAS_Catalog_2019
# 36 - KEGG_2016
# 37 - NCI-Nature_2015
# 38 - NCI-Nature_2016
# 39 - CCLE_Proteomics_2020
# 40 - PheWeb_2019
# 41 - RNA-Seq_Disease_Gene_and_Drug_Signatures_from_GEO
# 42 - LINCS_L1000_Chem_Pert_down
# 43 - Old_CMAP_up
# 44 - LINCS_L1000_Ligand_Perturbations_down
# 45 - Enrichr_Users_Contributed_Lists_2020
# 46 - NIH_Funded_PIs_2017_Human_GeneRIF
# 47 - Jensen_TISSUES
# 48 - Azimuth_Cell_Types_2021
# 49 - Panther_2016
# 50 - DisGeNET
# 51 - LINCS_L1000_Ligand_Perturbations_up
# 52 - Rare_Diseases_AutoRIF_Gene_Lists
# 53 - TargetScan_microRNA
# 54 - Achilles_fitness_increase
# 55 - Panther_2015
# 56 - WikiPathways_2019_Mouse
# 57 - ARCHS4_TFs_Coexp
# 58 - LINCS_L1000_Chem_Pert_up
# 59 - MSigDB_Oncogenic_Signatures
# 60 - Gene_Perturbations_from_GEO_down
# 61 - Table_Mining_of_CRISPR_Studies
# 62 - Rare_Diseases_GeneRIF_Gene_Lists
# 63 - Ligand_Perturbations_from_GEO_down
# 64 - SILAC_Phosphoproteomics
# 65 - Ligand_Perturbations_from_GEO_up
# 66 - Drug_Perturbations_from_GEO_up
# 67 - MGI_Mammalian_Phenotype_Level_4_2021
# 68 - Allen_Brain_Atlas_10x_scRNA_2021
# 69 - ClinVar_2019
# 70 - KEA_2015
# 71 - KEA_2013
# 72 - Chromosome_Location
# 73 - Microbe_Perturbations_from_GEO_up
# 74 - COVID-19_Related_Gene_Sets_2021
# 75 - MGI_Mammalian_Phenotype_Level_4_2019
# 76 - ARCHS4_IDG_Coexp
# 77 - NIH_Funded_PIs_2017_AutoRIF_ARCHS4_Predictions
# 78 - lncHUB_lncRNA_Co-Expression
# 79 - DrugMatrix
# 80 - Virus_Perturbations_from_GEO_down
# 81 - huMAP
# 82 - L1000_Kinase_and_GPCR_Perturbations_down
# 83 - Elsevier_Pathway_Collection
# 84 - NIH_Funded_PIs_2017_Human_AutoRIF
# 85 - RNAseq_Automatic_GEO_Signatures_Mouse_Down
# 86 - ESCAPE
# 87 - UK_Biobank_GWAS_v1
# 88 - Aging_Perturbations_from_GEO_up
# 89 - Human_Phenotype_Ontology
# 90 - dbGaP
# 91 - SubCell_BarCode
# 92 - Transcription_Factor_PPIs
# 93 - GO_Cellular_Component_2017b
# 94 - MSigDB_Hallmark_2020
# 95 - BioPlanet_2019
# 96 - HDSigDB_Human_2021
# 97 - GTEx_Tissue_Expression_Down
# 98 - Tissue_Protein_Expression_from_Human_Proteome_Map
# 99 - Epigenomics_Roadmap_HM_ChIP-seq
# 100 - PhenGenI_Association_2021
# 101 - MCF7_Perturbations_from_GEO_down
# 102 - ProteomicsDB_2020
# 103 - Virus-Host_PPI_P-HIPSTer_2020
# 104 - OMIM_Expanded
# 105 - Genes_Associated_with_NIH_Grants
# 106 - CellMarker_Augmented_2021
# 107 - ENCODE_and_ChEA_Consensus_TFs_from_ChIP-X
# 108 - HDSigDB_Mouse_2021
# 109 - Jensen_COMPARTMENTS
# 110 - ChEA_2015
# 111 - ChEA_2016
# 112 - KEGG_2019_Mouse
# 113 - Drug_Perturbations_from_GEO_2014
# 114 - TargetScan_microRNA_2017
# 115 - KEGG_2021_Mouse
# 116 - Allen_Brain_Atlas_down
# 117 - BioCarta_2013
# 118 - Reactome_2013
# 119 - WikiPathways_2019_Human
# 120 - Gene_Perturbations_from_GEO_up
# 121 - GO_Cellular_Component_2015
# 122 - GO_Cellular_Component_2013
# 123 - BioCarta_2016
# 124 - Reactome_2015
# 125 - BioCarta_2015
# 126 - GO_Cellular_Component_2018
# 127 - Reactome_2016
# 128 - GO_Cellular_Component_2017
# 129 - GO_Cellular_Component_2021
# 130 - WikiPathway_2021_Mouse
# 131 - ENCODE_TF_ChIP-seq_2015
# 132 - ENCODE_TF_ChIP-seq_2014
# 133 - RNAseq_Automatic_GEO_Signatures_Mouse_Up
# 134 - GO_Molecular_Function_2017b
# 135 - MGI_Mammalian_Phenotype_2013
# 136 - HMS_LINCS_KinomeScan
# 137 - NCI-60_Cancer_Cell_Lines
# 138 - MGI_Mammalian_Phenotype_2017
# 139 - Rare_Diseases_GeneRIF_ARCHS4_Predictions
# 140 - Virus_Perturbations_from_GEO_up
# 141 - Enrichr_Libraries_Most_Popular_Genes
# 142 - Orphanet_Augmented_2021
# 143 - GO_Biological_Process_2021
# 144 - TRANSFAC_and_JASPAR_PWMs
# 145 - Rare_Diseases_AutoRIF_ARCHS4_Predictions
# 146 - COVID-19_Related_Gene_Sets
# 147 - Kinase_Perturbations_from_GEO_up
# 148 - Descartes_Cell_Types_and_Tissue_2021
# 149 - TF_Perturbations_Followed_by_Expression
# 150 - GTEx_Aging_Signatures_2021
# 151 - Tissue_Protein_Expression_from_ProteomicsDB
# 152 - Aging_Perturbations_from_GEO_down
# 153 - GO_Biological_Process_2013
# 154 - GO_Biological_Process_2017b
# 155 - GO_Biological_Process_2018
# 156 - CORUM
# 157 - Phosphatase_Substrates_from_DEPOD
# 158 - BioPlex_2017
# 159 - GO_Biological_Process_2015
# 160 - TRRUST_Transcription_Factors_2019
# 161 - GO_Biological_Process_2017
# 162 - Pfam_InterPro_Domains
# 163 - HuBMAP_ASCT_plus_B_augmented_w_RNAseq_Coexpression
# 164 - Pfam_Domains_2019
# 165 - Allen_Brain_Atlas_up
# 166 - NURSA_Human_Endogenous_Complexome
# 167 - Genome_Browser_PWMs
# 168 - HumanCyc_2015
# 169 - HumanCyc_2016
# 170 - Chromosome_Location_hg19
# 171 - ChEA_2013
# 172 - Mouse_Gene_Atlas
# 173 - miRTarBase_2017
# 174 - Jensen_DISEASES
# 175 - RNAseq_Automatic_GEO_Signatures_Human_Down
# 176 - ARCHS4_Kinases_Coexp
# 177 - Microbe_Perturbations_from_GEO_down
# 178 - PanglaoDB_Augmented_2021
# 179 - ENCODE_Histone_Modifications_2013
# 180 - Achilles_fitness_decrease
# 181 - ENCODE_Histone_Modifications_2015
# 182 - DSigDB
# 183 - Disease_Perturbations_from_GEO_down
# 184 - DepMap_WG_CRISPR_Screens_Broad_CellLines_2019
# 185 - Drug_Perturbations_from_GEO_down
# 186 - GO_Molecular_Function_2021
# 187 - GO_Molecular_Function_2017
# 188 - GO_Molecular_Function_2018
# 189 - GO_Molecular_Function_2013
# 190 - GO_Molecular_Function_2015
# 191 - TG_GATES_2020
# 192 - KEGG_2021_Human
# 193 - HMDB_Metabolites
# Calibration: 100%|██████████| 25/25 [00:35<00:00,  1.41s/it]
# Enrichment : 100%|██████████| 320/320 [00:00<00:00, 569.67it/s]

# %%
import urllib.request
import prismx as px
import os

# %%
px.bridge_gsea()
